# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas_datareader.data as web

from pandas_datareader import wb
from datetime import datetime

start = datetime(2016, 9, 1)
end = datetime(2017, 3, 1)

#from FRED
# gdp = web.DataReader('GDP', 'fred', start, end)
# gdp

##from yahoo
# F = web.DataReader('F', 'yahoo', start, end)
# F

##world bank
# matches = wb.search('gdp.*capita.*const')
# matches
# data = wb.download(indicator='NY.GDP.PCAP.KD', country=['US', 'CA', 'MX'], start=2005, end=2008)
# data

# data = wb.download(indicator='6.0.GDPpc_constant', country=['US', 'CA', 'MX'], start=2005, end=2008)
# data

from pandas_datareader import data
exchange_rate = data.DataReader(['DEXJPUS', 'DEXCHUS'] ,'fred')

# %%
import yfinance as yf
F = yf.Ticker("F")
F.info

[F.info.get(key) for key in ['country','sector','industry','exchange']]


hist = F.history(period="max")
hist.head()
F.actions
F.dividends
F.splits
F.financials
F.balance_sheet
F.cashflow
F.options
opt = F.option_chain('2021-02-04')
opt.calls
opt.puts

# pip install yfinance --upgrade --no-cache-dir
# Out:
# {'zip': '48126',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 187000,
# ...
